# %%
import cv2

# %%
img=cv2.imread("group.jpg")

# %%
h,w=img.shape[:2]

# %%
print(h,w)
# Out:
# 408 612

# %%
# Extracting the RGB values of a pixel

# %%
(B,G,R)=img[100,100]

# %%
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("Screenshot_20210515_213048.jpg")
plt.imshow(img)
plt.show()

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
IMG_RGH=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
face=cv2.CascadeClassifier("C:/Users/manda/Downloads/Telegram Desktop/haarcascade_frontalface_default.xml")

# %%
found=face.detectMultiScale(img_gray,minSize=(20,20))

# %%
amount_found=len(found)

# %% [markdown]
# if amount_found !=

# %%
if amount_found !=0:
    for (x,y,width,height) in found:
        cv2.rectangle(IMG_RGH,(x,y),(x+height,y+width),(0,255,0),5)

# %%
plt.subplot(1,1,1)
plt.imshow(IMG_RGH)
plt.show()
