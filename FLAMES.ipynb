# %%
pers1=input("enter first person name: ")
pers2=input("enter second  person name :")
pers1.replace(" ","")
pers2.replace(" ","")
x=list(pers1)
y=list(pers2)
for i in x:
    if i in y:
        x.remove(i)
        y.remove(i)
        
c=len(x)+len(y)
result=["Friends","Lovers","Affection","Marriage","Enemies","Siblings"]

while len(result)>1:
    index=c%len(result)-1
    if index>=0:
        right=result[index+1:]
        left=result[:index]
        result=right+left
    else:
        result=result[1:len(result)]
print(result)
# Out:
# enter first person name: supraja
# enter second  person name :dinesh
# ['Marriage']

# %%
# s1=input("Enter First Name : ")
# s2=input("Enter Second Name : ")
# name1=list(s1.lower())
# name2=list(s2.lower())
# for i,x in enumerate(name1):
#     j="".join(name2).find(name1[i])
#     if(j!=-1):
#         name1[i]='*'
#         name2[j]='*' 
        
# x=lambda x: True if x!='*' else False 
# a=[]
# a.extend(list(filter(x,name1)))
# a.extend(list(filter(x,name2)))
# n=len(a)

# flames=list("FLAMES")
# i=0
# c=0
# while len(list(filter(x,flames)))!=1:
#     if i==6:
#         i=0      
#     if flames[i]!='*':
#         c+=1      
#     if c==n:
#         flames[i]='*'
#         c=0       
#     i+=1
# result=''.join(list(filter(x,flames)))

# flamesDict={
#     'F':'Friend',
#     'L':'Love',
#     'A':'Affection',
#     'M':'Marriage',
#     'E':'Enemy',
#     'S':'Sibling',
# }
# print("{} is {}'s {}".format(s1,s2,flamesDict[result]))

# %% [markdown]
# x1=input("Enter first name:")
#
# y1=input("Enter second name:")
#
# x=x1.replace(" ","")
#
# y=y1.replace(" ","")
#
# x=list(x)
#
# y=list(y)
#
# for i in x[:]:
#
# if i in y:
#
# x.remove(i)
#
# y.remove(i)
#
# count=12
#
#  print(count)
#
# count=12
#
# result = ["Friends", "Love", "Affection", "Marriage", "Enemy", "Siblings"]
#
#
# while len(result) > 1 :
#
# split_index = (count % len(result)-1 )
#
# if (split_index>=0) :
#
# right = result[split_index + 1 : ]
#
# left = result[ : split_index]
#
# result = right + left
#
# else :
#
# result = result[ 1: len(result)]
#
# print(f"the relation between {x1} and {y1} is {result}")

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


from tkinter import*


# In[2]:


root = Tk()


# In[3]:


root.geometry('500x500')


# In[4]:


root.title("WEIGHT CONVERSION")


# In[5]:


def convertion():
    z = kg.get()
    z = int(z)
    grams = 1000*z
    pounds = 100*z
    Label(root,text=grams).place(x=200,y=125)
    Label(root,text=pounds).place(x=200,y=145)


# In[6]:


title1 = Label(root,text='WEIGHT CONVERSION').place(x=250,y=10)
w = Label(root,text='Weight').place(x=40,y=60)
btn = Button(root,text='CONVERT',bd='5',command=convertion).place(x=40,y=80)
gram = Label(root,text='In_Grams').place(x=40,y=125)
pound = Label(root,text='In_Pounds').place(x=40,y=145)
kg = StringVar()
w_input = Entry(root,width='30',textvariable=kg).place(x=150,y=60)


# In[ ]:


root.mainloop()


# In[ ]:
